# %%
import pandas as pd

tsv_path = "/home/henry/Projects/ASR/dataset/en/train.tsv"
df = pd.read_csv(tsv_path, sep='\t')
df
# Out:
# /tmp/ipykernel_3339/2087272178.py:4: DtypeWarning: Columns (0: sentence_domain) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
#                                                  client_id  \
# 0        c6efb55544228db36cf26a0a4477bd0896c40ed3e06451...
# 1        c6efb55544228db36cf26a0a4477bd0896c40ed3e06451...
# 2        c6efb55544228db36cf26a0a4477bd0896c40ed3e06451...
# 3        c6fb37dbc9f1279606362857a602bb1435ce5aaab6fe20...
# 4        c6fb37dbc9f1279606362857a602bb1435ce5aaab6fe20...
# ...                                                    ...
# 1147460  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 1147461  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 1147462  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 1147463  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 1147464  372293e65cdab88771e028a4351651ab2eff64438ddafc...
#
#                                  path  \
# ...

# %%
df.head()
# Out:
#                                            client_id  \
# 0  c6efb55544228db36cf26a0a4477bd0896c40ed3e06451...
# 1  c6efb55544228db36cf26a0a4477bd0896c40ed3e06451...
# 2  c6efb55544228db36cf26a0a4477bd0896c40ed3e06451...
# 3  c6fb37dbc9f1279606362857a602bb1435ce5aaab6fe20...
# 4  c6fb37dbc9f1279606362857a602bb1435ce5aaab6fe20...
#
#                            path  \
# 0  common_voice_en_32818178.mp3
# 1  common_voice_en_32818179.mp3
# 2  common_voice_en_32818181.mp3
# 3  common_voice_en_35128760.mp3
# 4  common_voice_en_35128762.mp3
#
#                                          sentence_id  \
# 0  9a0040ffd6c8e25e49ef82e03284e96298070e53b9569e...
# 1  98be3e64eccf03d9b4926a209c550ace25721d536b4002...
# 2  99b561c8bcc8d5291bc98144cc0a9ca14c865c2837b80b...
# 3  c544f8dd2ca0ebe85e44b10c3cdeb987f72f7631ea74ee...
# 4  c4ffcdf7d28dd1f0ec032d7a27562d862a1c1a67e08155...
#
#                                             sentence sentence_domain  \
# ...
